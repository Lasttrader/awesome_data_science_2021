# %%
import numpy as np
import pandas as pd
import shutil, os
import json
from io import StringIO
from IPython.display import display, HTML

#!pip install apyori
from apyori import apriori
import apyori

# %%
df = pd.read_csv('data.csv', header=None, usecols=np.arange(0,7))

# %%
df.fillna(method='ffill', axis=1, inplace=True)

# %%
df
# Out:
#             0              1              2              3              4  \
# 0       Lassi  Coffee Powder         Butter        Yougurt           Ghee
# 1        Ghee  Coffee Powder  Coffee Powder  Coffee Powder  Coffee Powder
# 2       Lassi     Tea Powder         Butter         Cheese         Cheese
# 3      Cheese     Tea Powder         Panner  Coffee Powder         Butter
# 4      Cheese        Yougurt  Coffee Powder          Sugar         Butter
# ...       ...            ...            ...            ...            ...
# 12521  Panner          Sugar          Bread           Milk         Cheese
# 12522   Sugar          Bread  Coffee Powder         Cheese         Cheese
# 12523   Bread         Cheese        Yougurt           Milk           Milk
# 12524    Ghee          Bread        Yougurt          Sugar         Cheese
# 12525  Panner        Yougurt          Bread          Bread          Bread
#
#                    5              6
# 0             Cheese         Cheese
# 1      Coffee Powder  Coffee Powder
# 2             Cheese         Cheese
# 3              Bread          Bread
# 4              Sweet          Sweet
# ...              ...            ...
# 12521         Cheese         Cheese
# 12522         Cheese         Cheese
# 12523           Milk           Milk
# 12524         Cheese         Cheese
# 12525          Bread          Bread
#
# [12526 rows x 7 columns]

# %% [markdown]
# # Apriori

# %%
# создаим из них матрицу
transactions = []
for i in range(0, df.shape[0]): 
    transactions.append([str(df.values[i,j]) for j in range(0, df.shape[1])])

# %%
# %%time
result = list(apriori(transactions, min_support = 0.004, min_confidence = 0.2, min_lift = 1, min_length = 2)) 
# строим ассоциативные правила
# Out:
# CPU times: user 12.6 s, sys: 48.2 ms, total: 12.6 s
# Wall time: 12.6 s

# %%
output = []

# преобразуем в датафрейм, чтобы посмотреть
for record in result:
    o = StringIO()
    apyori.dump_as_json(record, o)
    output.append(json.loads(o.getvalue())) 

data_df = pd.DataFrame(output)
data_df
# Out:
#                                                  items   support  \
# 0                                              [Bread]  0.422401
# 1                                             [Butter]  0.423280
# 2                                             [Cheese]  0.421044
# 3                                      [Coffee Powder]  0.422801
# 4                                               [Ghee]  0.422322
# ..                                                 ...       ...
# 157                       [Lassi, Milk, Panner, Sweet]  0.031055
# 158                 [Lassi, Panner, Sweet, Tea Powder]  0.032812
# 159                  [Milk, Panner, Sugar, Tea Powder]  0.029459
# 160          [Bread, Cheese, Milk, Panner, Tea Powder]  0.010778
# 161  [Coffee Powder, Lassi, Panner, Sweet, Tea Powder]  0.012135
#
#                                     ordered_statistics
# 0    [{'items_base': [], 'items_add': ['Bread'], 'c...
# 1    [{'items_base': [], 'items_add': ['Butter'], '...
# 2    [{'items_base': [], 'items_add': ['Cheese'], '...
# 3    [{'items_base': [], 'items_add': ['Coffee Powd...
# 4    [{'items_base': [], 'items_add': ['Ghee'], 'co...
# ..                                                 ...
# 157  [{'items_base': ['Milk', 'Panner', 'Sweet'], '...
# 158  [{'items_base': ['Lassi', 'Panner', 'Sweet'], ...
# 159  [{'items_base': ['Milk', 'Panner', 'Tea Powder...
# 160  [{'items_base': ['Cheese', 'Milk', 'Panner', '...
# 161  [{'items_base': ['Coffee Powder', 'Lassi', 'Pa...
#
# [162 rows x 3 columns]

# %% [markdown]
# # Eclat

# %%
class Eclat:
    #инициализация объекта класса
    def __init__(self, min_support = 0.01, max_items = 5, min_items = 2):
        self.min_support = min_support
        self.max_items = max_items
        self.min_items = min_items
        self.item_lst = list()
        self.item_len = 0
        self.item_dict = dict()
        self.final_dict = dict()
        self.data_size = 0
    
    #создание словаря из ненулевых объектов из всех транзакций (вертикальный датасет)
    def read_data(self, dataset):
        for index, row in dataset.iterrows():
            row_wo_na = set(row[0])
            for item in row_wo_na:
                item = item.strip()
                if item in self.item_dict:
                    self.item_dict[item][0] += 1
                else:
                    self.item_dict.setdefault(item, []).append(1)
                self.item_dict[item].append(index)
        #задаем переменные экземпляра (instance variables)
        self.data_size = dataset.shape[0]
        self.item_lst = list(self.item_dict.keys())
        self.item_len = len(self.item_lst)
        self.min_support = self.min_support * self.data_size
        #print ("min_supp", self.min_support)
        
    #рекурсивный метод для поиска всех ItemSet по алгоритму Eclat
    #структура данных: {Item: [Supp number, tid1, tid2, tid3, ...]}
    def recur_eclat(self, item_name, tids_array, minsupp, num_items, k_start):
        if tids_array[0] >= minsupp and num_items <= self.max_items:
            for k in range(k_start+1, self.item_len):
                if self.item_dict[self.item_lst[k]][0] >= minsupp:
                    new_item = item_name + " | " + self.item_lst[k]
                    new_tids = np.intersect1d(tids_array[1:], self.item_dict[self.item_lst[k]][1:])
                    new_tids_size = new_tids.size
                    new_tids = np.insert(new_tids, 0, new_tids_size)
                    if new_tids_size >= minsupp:
                        if num_items >= self.min_items: self.final_dict.update({new_item: new_tids})
                        self.recur_eclat(new_item, new_tids, minsupp, num_items+1, k)
    
    #последовательный вызов функций определенных выше
    def fit(self, dataset):
        i = 0
        self.read_data(dataset)
        for w in self.item_lst:
            self.recur_eclat(w, self.item_dict[w], self.min_support, 2, i)
            i+=1
        return self
        
    #вывод в форме словаря {ItemSet: support(ItemSet)}
    def transform(self):
        return {k: "{0:.2f}%".format((v[0]+0.0)/self.data_size*100) for k, v in self.final_dict.items()}

# %%
model = Eclat(min_support = 0.01, max_items = 4, min_items = 3)
model.fit(df)

# %%
model.transform()
# Out:
# {'s | i | a': '7.95%',
#  's | i | a | L': '7.95%',
#  's | i | L': '7.95%',
#  's | a | L': '7.95%',
#  's | e | h': '8.40%',
#  's | e | h | C': '8.40%',
#  's | e | C': '8.40%',
#  's | h | C': '8.40%',
#  'i | a | L': '7.95%',
#  'i | k | l': '8.52%',
#  'i | k | l | M': '8.52%',
#  'i | k | M': '8.52%',
#  'i | l | M': '8.52%',
#  'a | e | r': '24.51%',
#  'a | e | r | w': '8.24%',
#  'a | e | r | B': '8.04%',
#  'a | e | r | n': '8.23%',
#  'a | e | r | P': '16.47%',
#  'a | e | r | d': '16.28%',
#  'a | e | r | ': '8.24%',
#  'a | e | r | o': '8.24%',
#  'a | e | r | T': '8.24%',
#  'a | e | w': '8.24%',
#  'a | e | w | P': '8.24%',
#  'a | e | w | d': '8.24%',
#  'a | e | w | ': '8.24%',
#  'a | e | w | o': '8.24%',
#  'a | e | w | T': '8.24%',
#  'a | e | B': '8.04%',
#  'a | e | B | d': '8.04%',
#  'a | e | n': '8.23%',
#  'a | e | n | P': '8.23%',
#  'a | e | P': '16.47%',
#  'a | e | P | d': '8.24%',
#  'a | e | P | ': '8.24%',
#  'a | e | P | o': '8.24%',
#  'a | e | P | T': '8.24%',
#  'a | e | d': '16.28%',
#  'a | e | d | ': '8.24%',
#  'a | e | d | o': '8.24%',
#  'a | e | d | T': '8.24%',
#  'a | e | ': '8.24%',
#  'a | e |  | o': '8.24%',
#  'a | e |  | T': '8.24%',
#  'a | e | o': '8.24%',
#  'a | e | o | T': '8.24%',
#  'a | e | T': '8.24%',
#  'a | r | u': '8.65%',
#  'a | r | u | g': '8.65%',
#  'a | r | u | S': '8.65%',
#  'a | r | g': '8.65%',
#  'a | r | g | S': '8.65%',
#  'a | r | S': '8.65%',
#  'a | r | w': '8.24%',
#  'a | r | w | P': '8.24%',
#  'a | r | w | d': '8.24%',
#  'a | r | w | ': '8.24%',
#  'a | r | w | o': '8.24%',
#  'a | r | w | T': '8.24%',
#  'a | r | B': '8.04%',
#  'a | r | B | d': '8.04%',
#  'a | r | n': '8.23%',
#  'a | r | n | P': '8.23%',
#  'a | r | P': '16.47%',
#  'a | r | P | d': '8.24%',
#  'a | r | P | ': '8.24%',
#  'a | r | P | o': '8.24%',
#  'a | r | P | T': '8.24%',
#  'a | r | d': '16.28%',
#  'a | r | d | ': '8.24%',
#  'a | r | d | o': '8.24%',
#  'a | r | d | T': '8.24%',
#  'a | r | ': '8.24%',
#  'a | r |  | o': '8.24%',
#  'a | r |  | T': '8.24%',
#  'a | r | o': '8.24%',
#  'a | r | o | T': '8.24%',
#  'a | r | T': '8.24%',
#  'a | u | g': '8.65%',
#  'a | u | g | S': '8.65%',
#  'a | u | S': '8.65%',
#  'a | g | S': '8.65%',
#  'a | w | P': '8.24%',
#  'a | w | P | d': '8.24%',
#  'a | w | P | ': '8.24%',
#  'a | w | P | o': '8.24%',
#  'a | w | P | T': '8.24%',
#  'a | w | d': '8.24%',
#  'a | w | d | ': '8.24%',
#  'a | w | d | o': '8.24%',
#  'a | w | d | T': '8.24%',
#  'a | w | ': '8.24%',
#  'a | w |  | o': '8.24%',
#  'a | w |  | T': '8.24%',
#  'a | w | o': '8.24%',
#  'a | w | o | T': '8.24%',
#  'a | w | T': '8.24%',
#  'a | B | d': '8.04%',
#  'a | n | P': '8.23%',
#  'a | P | d': '8.24%',
#  'a | P | d | ': '8.24%',
#  'a | P | d | o': '8.24%',
#  'a | P | d | T': '8.24%',
#  'a | P | ': '8.24%',
#  'a | P |  | o': '8.24%',
#  'a | P |  | T': '8.24%',
#  'a | P | o': '8.24%',
#  'a | P | o | T': '8.24%',
#  'a | P | T': '8.24%',
#  'a | d | ': '8.24%',
#  'a | d |  | o': '8.24%',
#  'a | d |  | T': '8.24%',
#  'a | d | o': '8.24%',
#  'a | d | o | T': '8.24%',
#  'a | d | T': '8.24%',
#  'a |  | o': '8.24%',
#  'a |  | o | T': '8.24%',
#  'a |  | T': '8.24%',
#  'a | o | T': '8.24%',
#  'G | e | h': '8.32%',
#  'e | h | C': '8.40%',
#  'e | C | r': '8.45%',
#  'e | C | r | w': '8.45%',
#  'e | C | r | P': '8.45%',
#  'e | C | r | d': '8.45%',
#  'e | C | r | ': '8.45%',
#  'e | C | r | o': '8.45%',
#  'e | C | r | f': '8.45%',
#  'e | C | w': '8.45%',
#  'e | C | w | P': '8.45%',
#  'e | C | w | d': '8.45%',
#  'e | C | w | ': '8.45%',
#  'e | C | w | o': '8.45%',
#  'e | C | w | f': '8.45%',
#  'e | C | P': '8.45%',
#  'e | C | P | d': '8.45%',
#  'e | C | P | ': '8.45%',
#  'e | C | P | o': '8.45%',
#  'e | C | P | f': '8.45%',
#  'e | C | d': '8.45%',
#  'e | C | d | ': '8.45%',
#  'e | C | d | o': '8.45%',
#  'e | C | d | f': '8.45%',
#  'e | C | ': '8.45%',
#  'e | C |  | o': '8.45%',
#  'e | C |  | f': '8.45%',
#  'e | C | o': '8.45%',
#  'e | C | o | f': '8.45%',
#  'e | C | f': '8.45%',
#  'e | r | u': '8.45%',
#  'e | r | u | t': '8.45%',
#  'e | r | u | B': '8.45%',
#  'e | r | w': '16.69%',
#  'e | r | w | P': '16.69%',
#  'e | r | w | d': '16.69%',
#  'e | r | w | ': '16.69%',
#  'e | r | w | o': '16.69%',
#  'e | r | w | f': '8.45%',
#  'e | r | w | T': '8.24%',
#  'e | r | t': '8.45%',
#  'e | r | t | B': '8.45%',
#  'e | r | B': '16.49%',
#  'e | r | B | d': '8.04%',
#  'e | r | n': '8.23%',
#  'e | r | n | P': '8.23%',
#  'e | r | P': '24.92%',
#  'e | r | P | d': '16.69%',
#  'e | r | P | ': '16.69%',
#  'e | r | P | o': '16.69%',
#  'e | r | P | f': '8.45%',
#  'e | r | P | T': '8.24%',
#  'e | r | d': '24.72%',
#  'e | r | d | ': '16.69%',
#  'e | r | d | o': '16.69%',
#  'e | r | d | f': '8.45%',
#  'e | r | d | T': '8.24%',
#  'e | r | ': '16.69%',
#  'e | r |  | o': '16.69%',
#  'e | r |  | f': '8.45%',
#  'e | r |  | T': '8.24%',
#  'e | r | o': '16.69%',
#  'e | r | o | f': '8.45%',
#  'e | r | o | T': '8.24%',
#  'e | r | f': '8.45%',
#  'e | r | T': '8.24%',
#  'e | u | t': '8.45%',
#  'e | u | t | B': '8.45%',
#  'e | u | B': '8.45%',
#  'e | S | w': '8.19%',
#  'e | S | w | t': '8.19%',
#  'e | S | t': '8.19%',
#  'e | w | t': '8.19%',
#  'e | w | P': '16.69%',
#  'e | w | P | d': '16.69%',
#  'e | w | P | ': '16.69%',
#  'e | w | P | o': '16.69%',
#  'e | w | P | f': '8.45%',
#  'e | w | P | T': '8.24%',
#  'e | w | d': '16.69%',
#  'e | w | d | ': '16.69%',
#  'e | w | d | o': '16.69%',
#  'e | w | d | f': '8.45%',
#  'e | w | d | T': '8.24%',
#  'e | w | ': '16.69%',
#  'e | w |  | o': '16.69%',
#  'e | w |  | f': '8.45%',
#  'e | w |  | T': '8.24%',
#  'e | w | o': '16.69%',
#  'e | w | o | f': '8.45%',
#  'e | w | o | T': '8.24%',
#  'e | w | f': '8.45%',
#  'e | w | T': '8.24%',
#  'e | t | B': '8.45%',
#  'e | B | d': '8.04%',
#  'e | n | P': '8.23%',
#  'e | P | d': '16.69%',
#  'e | P | d | ': '16.69%',
#  'e | P | d | o': '16.69%',
#  'e | P | d | f': '8.45%',
#  'e | P | d | T': '8.24%',
#  'e | P | ': '16.69%',
#  'e | P |  | o': '16.69%',
#  'e | P |  | f': '8.45%',
#  'e | P |  | T': '8.24%',
#  'e | P | o': '16.69%',
#  'e | P | o | f': '8.45%',
#  'e | P | o | T': '8.24%',
#  'e | P | f': '8.45%',
#  'e | P | T': '8.24%',
#  'e | d | ': '16.69%',
#  'e | d |  | o': '16.69%',
#  'e | d |  | f': '8.45%',
#  'e | d |  | T': '8.24%',
#  'e | d | o': '16.69%',
#  'e | d | o | f': '8.45%',
#  'e | d | o | T': '8.24%',
#  'e | d | f': '8.45%',
#  'e | d | T': '8.24%',
#  'e |  | o': '16.69%',
#  'e |  | o | f': '8.45%',
#  'e |  | o | T': '8.24%',
#  'e |  | f': '8.45%',
#  'e |  | T': '8.24%',
#  'e | o | f': '8.45%',
#  'e | o | T': '8.24%',
#  'C | r | w': '8.45%',
#  'C | r | w | P': '8.45%',
#  'C | r | w | d': '8.45%',
#  'C | r | w | ': '8.45%',
#  'C | r | w | o': '8.45%',
#  'C | r | w | f': '8.45%',
#  'C | r | P': '8.45%',
#  'C | r | P | d': '8.45%',
#  'C | r | P | ': '8.45%',
#  'C | r | P | o': '8.45%',
#  'C | r | P | f': '8.45%',
#  'C | r | d': '8.45%',
#  'C | r | d | ': '8.45%',
#  'C | r | d | o': '8.45%',
#  'C | r | d | f': '8.45%',
#  'C | r | ': '8.45%',
#  'C | r |  | o': '8.45%',
#  'C | r |  | f': '8.45%',
#  'C | r | o': '8.45%',
#  'C | r | o | f': '8.45%',
#  'C | r | f': '8.45%',
#  'C | w | P': '8.45%',
#  'C | w | P | d': '8.45%',
#  'C | w | P | ': '8.45%',
#  'C | w | P | o': '8.45%',
#  'C | w | P | f': '8.45%',
#  'C | w | d': '8.45%',
#  'C | w | d | ': '8.45%',
#  'C | w | d | o': '8.45%',
#  'C | w | d | f': '8.45%',
#  'C | w | ': '8.45%',
#  'C | w |  | o': '8.45%',
#  'C | w |  | f': '8.45%',
#  'C | w | o': '8.45%',
#  'C | w | o | f': '8.45%',
#  'C | w | f': '8.45%',
#  'C | P | d': '8.45%',
#  'C | P | d | ': '8.45%',
#  'C | P | d | o': '8.45%',
#  'C | P | d | f': '8.45%',
#  'C | P | ': '8.45%',
#  'C | P |  | o': '8.45%',
#  'C | P |  | f': '8.45%',
#  'C | P | o': '8.45%',
#  'C | P | o | f': '8.45%',
#  'C | P | f': '8.45%',
#  'C | d | ': '8.45%',
#  'C | d |  | o': '8.45%',
#  'C | d |  | f': '8.45%',
#  'C | d | o': '8.45%',
#  'C | d | o | f': '8.45%',
#  'C | d | f': '8.45%',
#  'C |  | o': '8.45%',
#  'C |  | o | f': '8.45%',
#  'C |  | f': '8.45%',
#  'C | o | f': '8.45%',
#  'r | u | g': '17.22%',
#  'r | u | g | S': '8.65%',
#  'r | u | g | t': '8.57%',
#  'r | u | g | o': '8.57%',
#  'r | u | g | Y': '8.57%',
#  'r | u | S': '8.65%',
#  'r | u | t': '17.01%',
#  'r | u | t | B': '8.45%',
#  'r | u | t | o': '8.57%',
#  'r | u | t | Y': '8.57%',
#  'r | u | B': '8.45%',
#  'r | u | o': '8.57%',
#  'r | u | o | Y': '8.57%',
#  'r | u | Y': '8.57%',
#  'r | g | S': '8.65%',
#  'r | g | t': '8.57%',
#  'r | g | t | o': '8.57%',
#  'r | g | t | Y': '8.57%',
#  'r | g | o': '8.57%',
#  'r | g | o | Y': '8.57%',
#  'r | g | Y': '8.57%',
#  'r | w | P': '16.69%',
#  'r | w | P | d': '16.69%',
#  'r | w | P | ': '16.69%',
#  'r | w | P | o': '16.69%',
#  'r | w | P | f': '8.45%',
#  'r | w | P | T': '8.24%',
#  'r | w | d': '16.69%',
#  'r | w | d | ': '16.69%',
#  'r | w | d | o': '16.69%',
#  'r | w | d | f': '8.45%',
#  'r | w | d | T': '8.24%',
#  'r | w | ': '16.69%',
#  'r | w |  | o': '16.69%',
#  'r | w |  | f': '8.45%',
#  'r | w |  | T': '8.24%',
#  'r | w | o': '16.69%',
#  'r | w | o | f': '8.45%',
#  'r | w | o | T': '8.24%',
#  'r | w | f': '8.45%',
#  'r | w | T': '8.24%',
#  'r | t | B': '8.45%',
#  'r | t | o': '8.57%',
#  'r | t | o | Y': '8.57%',
#  'r | t | Y': '8.57%',
#  'r | B | d': '8.04%',
#  'r | n | P': '8.23%',
#  'r | P | d': '16.69%',
#  'r | P | d | ': '16.69%',
#  'r | P | d | o': '16.69%',
#  'r | P | d | f': '8.45%',
#  'r | P | d | T': '8.24%',
#  'r | P | ': '16.69%',
#  'r | P |  | o': '16.69%',
#  'r | P |  | f': '8.45%',
#  'r | P |  | T': '8.24%',
#  'r | P | o': '16.69%',
#  'r | P | o | f': '8.45%',
#  'r | P | o | T': '8.24%',
#  'r | P | f': '8.45%',
#  'r | P | T': '8.24%',
#  'r | d | ': '16.69%',
#  'r | d |  | o': '16.69%',
#  'r | d |  | f': '8.45%',
#  'r | d |  | T': '8.24%',
#  'r | d | o': '16.69%',
#  'r | d | o | f': '8.45%',
#  'r | d | o | T': '8.24%',
#  'r | d | f': '8.45%',
#  'r | d | T': '8.24%',
#  'r |  | o': '16.69%',
#  'r |  | o | f': '8.45%',
#  'r |  | o | T': '8.24%',
#  'r |  | f': '8.45%',
#  'r |  | T': '8.24%',
#  'r | o | f': '8.45%',
#  'r | o | Y': '8.57%',
#  'r | o | T': '8.24%',
#  'u | g | S': '8.65%',
#  'u | g | t': '8.57%',
#  'u | g | t | o': '8.57%',
#  'u | g | t | Y': '8.57%',
#  'u | g | o': '8.57%',
#  'u | g | o | Y': '8.57%',
#  'u | g | Y': '8.57%',
#  'u | t | B': '8.45%',
#  'u | t | o': '8.57%',
#  'u | t | o | Y': '8.57%',
#  'u | t | Y': '8.57%',
#  'u | o | Y': '8.57%',
#  'g | t | o': '8.57%',
#  'g | t | o | Y': '8.57%',
#  'g | t | Y': '8.57%',
#  'g | o | Y': '8.57%',
#  'S | w | t': '8.19%',
#  'w | P | d': '16.69%',
#  'w | P | d | ': '16.69%',
#  'w | P | d | o': '16.69%',
#  'w | P | d | f': '8.45%',
#  'w | P | d | T': '8.24%',
#  'w | P | ': '16.69%',
#  'w | P |  | o': '16.69%',
#  'w | P |  | f': '8.45%',
#  'w | P |  | T': '8.24%',
#  'w | P | o': '16.69%',
#  'w | P | o | f': '8.45%',
#  'w | P | o | T': '8.24%',
#  'w | P | f': '8.45%',
#  'w | P | T': '8.24%',
#  'w | d | ': '16.69%',
#  'w | d |  | o': '16.69%',
#  'w | d |  | f': '8.45%',
#  'w | d |  | T': '8.24%',
#  'w | d | o': '16.69%',
#  'w | d | o | f': '8.45%',
#  'w | d | o | T': '8.24%',
#  'w | d | f': '8.45%',
#  'w | d | T': '8.24%',
#  'w |  | o': '16.69%',
#  'w |  | o | f': '8.45%',
#  'w |  | o | T': '8.24%',
#  'w |  | f': '8.45%',
#  'w |  | T': '8.24%',
#  'w | o | f': '8.45%',
#  'w | o | T': '8.24%',
#  't | o | Y': '8.57%',
#  'P | d | ': '16.69%',
#  'P | d |  | o': '16.69%',
#  'P | d |  | f': '8.45%',
#  'P | d |  | T': '8.24%',
#  'P | d | o': '16.69%',
#  'P | d | o | f': '8.45%',
#  'P | d | o | T': '8.24%',
#  'P | d | f': '8.45%',
#  'P | d | T': '8.24%',
#  'P |  | o': '16.69%',
#  'P |  | o | f': '8.45%',
#  'P |  | o | T': '8.24%',
#  'P |  | f': '8.45%',
#  'P |  | T': '8.24%',
#  'P | o | f': '8.45%',
#  'P | o | T': '8.24%',
#  'k | l | M': '8.52%',
#  'd |  | o': '16.69%',
#  'd |  | o | f': '8.45%',
#  'd |  | o | T': '8.24%',
#  'd |  | f': '8.45%',
#  'd |  | T': '8.24%',
#  'd | o | f': '8.45%',
#  'd | o | T': '8.24%',
#  ' | o | f': '8.45%',
#  ' | o | T': '8.24%'}

# %% [markdown]
# # FP-Growth

# %%
#!pip install pyfpgrowth
import pyfpgrowth

# %%
#Сгенериуем паттерны
patterns = pyfpgrowth.find_frequent_patterns(transactions, 2)
#Выучим правила
rules = pyfpgrowth.generate_association_rules(patterns, 1);
#Покажем
rules
# Out:
# {('Panner', 'Panner', 'Sugar', 'Sweet', 'Tea Powder', 'Yougurt'): (('Bread',),
#   1.0),
#  ('Ghee', 'Lassi', 'Panner', 'Panner', 'Sugar', 'Tea Powder'): (('Milk',),
#   1.0),
#  ('Cheese', 'Ghee', 'Milk', 'Panner', 'Panner', 'Yougurt'): (('Tea Powder',),
#   1.0),
#  ('Milk', 'Panner', 'Panner', 'Panner', 'Tea Powder', 'Yougurt'): (('Cheese',),
#   1.0),
#  ('Coffee Powder',
#   'Lassi',
#   'Panner',
#   'Panner',
#   'Tea Powder',
#   'Yougurt'): (('Sugar',), 1.0),
#  ('Cheese',
#   'Coffee Powder',
#   'Panner',
#   'Panner',
#   'Sweet',
#   'Yougurt'): (('Tea Powder',), 1.0),
#  ('Coffee Powder',
#   'Panner',
#   'Panner',
#   'Sweet',
#   'Tea Powder',
#   'Yougurt'): (('Cheese',), 1.0),
#  ('Bread',
#   'Cheese',
#   'Milk',
#   'Panner',
#   'Tea Powder',
#   'Tea Powder'): (('Sweet',), 1.0),
#  ('Cheese',
#   'Milk',
#   'Panner',
#   'Sweet',
#   'Tea Powder',
#   'Tea Powder'): (('Bread',), 1.0),
#  ('Butter',
#   'Panner',
#   'Sugar',
#   'Sweet',
#   'Tea Powder',
#   'Tea Powder'): (('Lassi',), 1.0),
#  ('Ghee', 'Panner', 'Sugar', 'Sweet', 'Tea Powder', 'Tea Powder'): (('Lassi',),
#   1.0),
#  ('Bread',
#   'Butter',
#   'Coffee Powder',
#   'Panner',
#   'Tea Powder',
#   'Tea Powder'): (('Lassi',), 1.0),
#  ('Bread',
#   'Panner',
#   'Tea Powder',
#   'Tea Powder',
#   'Tea Powder',
#   'Yougurt'): (('Sugar',), 1.0),
#  ('Cheese',
#   'Milk',
#   'Panner',
#   'Sugar',
#   'Tea Powder',
#   'Tea Powder'): (('Butter',), 1.0),
#  ('Butter', 'Lassi', 'Milk', 'Milk', 'Panner', 'Tea Powder'): (('Sweet',),
#   1.0),
#  ('Butter',
#   'Coffee Powder',
#   'Milk',
#   'Milk',
#   'Panner',
#   'Sweet'): (('Tea Powder',), 1.0),
#  ('Butter', 'Lassi', 'Lassi', 'Panner', 'Sweet', 'Tea Powder'): (('Milk',),
#   1.0),
#  ('Butter', 'Milk', 'Panner', 'Sugar', 'Sugar', 'Tea Powder'): (('Ghee',),
#   1.0),
#  ('Ghee', 'Milk', 'Panner', 'Tea Powder', 'Yougurt', 'Yougurt'): (('Sugar',),
#   1.0),
#  ('Cheese', 'Lassi', 'Lassi', 'Milk', 'Tea Powder', 'Yougurt'): (('Panner',),
#   1.0),
#  ('Cheese',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Panner',
#   'Sugar',
#   'Tea Powder'): (('Milk',), 1.0),
#  ('Bread',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Panner',
#   'Sweet',
#   'Tea Powder'): (('Milk',), 1.0),
#  ('Coffee Powder',
#   'Lassi',
#   'Lassi',
#   'Milk',
#   'Panner',
#   'Tea Powder'): (('Bread',), 1.0),
#  ('Cheese',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Panner',
#   'Sweet',
#   'Tea Powder'): (('Butter',), 1.0),
#  ('Butter',
#   'Ghee',
#   'Ghee',
#   'Panner',
#   'Sugar',
#   'Tea Powder'): (('Coffee Powder',), 1.0),
#  ('Butter',
#   'Lassi',
#   'Panner',
#   'Sugar',
#   'Yougurt',
#   'Yougurt'): (('Tea Powder',), 1.0),
#  ('Cheese',
#   'Coffee Powder',
#   'Panner',
#   'Sugar',
#   'Sugar',
#   'Sugar'): (('Tea Powder',), 1.0),
#  ('Bread', 'Sugar', 'Sugar', 'Sweet', 'Tea Powder', 'Yougurt'): (('Panner',),
#   1.0),
#  ('Ghee', 'Lassi', 'Milk', 'Panner', 'Panner', 'Yougurt'): (('Bread',), 1.0),
#  ('Ghee', 'Lassi', 'Lassi', 'Lassi', 'Sweet', 'Yougurt'): (('Panner',), 1.0),
#  ('Butter', 'Coffee Powder', 'Lassi', 'Lassi', 'Lassi', 'Sugar'): (('Panner',),
#   1.0),
#  ('Cheese', 'Ghee', 'Lassi', 'Sugar', 'Yougurt', 'Yougurt'): (('Panner',),
#   1.0),
#  ('Cheese', 'Lassi', 'Panner', 'Sugar', 'Yougurt', 'Yougurt'): (('Ghee',),
#   1.0),
#  ('Butter', 'Cheese', 'Lassi', 'Panner', 'Yougurt', 'Yougurt'): (('Sweet',),
#   1.0),
#  ('Butter',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Lassi',
#   'Sugar',
#   'Yougurt'): (('Panner',), 1.0),
#  ('Bread', 'Butter', 'Butter', 'Lassi', 'Panner', 'Yougurt'): (('Milk',), 1.0),
#  ('Bread', 'Cheese', 'Lassi', 'Milk', 'Milk', 'Yougurt'): (('Panner',), 1.0),
#  ('Cheese', 'Cheese', 'Lassi', 'Milk', 'Panner', 'Sweet'): (('Yougurt',), 1.0),
#  ('Cheese', 'Coffee Powder', 'Ghee', 'Ghee', 'Lassi', 'Panner'): (('Bread',),
#   1.0),
#  ('Butter', 'Cheese', 'Lassi', 'Panner', 'Sweet', 'Sweet'): (('Ghee',), 1.0),
#  ('Bread', 'Bread', 'Butter', 'Cheese', 'Lassi', 'Panner'): (('Sweet',), 1.0),
#  ('Bread', 'Butter', 'Ghee', 'Ghee', 'Panner', 'Sugar'): (('Lassi',), 1.0),
#  ('Butter', 'Butter', 'Milk', 'Panner', 'Sugar', 'Sweet'): (('Bread',), 1.0),
#  ('Bread',
#   'Butter',
#   'Butter',
#   'Cheese',
#   'Milk',
#   'Panner'): (('Coffee Powder',), 1.0),
#  ('Butter',
#   'Butter',
#   'Butter',
#   'Coffee Powder',
#   'Sweet',
#   'Yougurt'): (('Panner',), 1.0),
#  ('Butter',
#   'Cheese',
#   'Coffee Powder',
#   'Panner',
#   'Panner',
#   'Yougurt'): (('Milk',), 1.0),
#  ('Bread', 'Butter', 'Ghee', 'Panner', 'Panner', 'Sweet'): (('Sugar',), 1.0),
#  ('Butter', 'Cheese', 'Panner', 'Panner', 'Panner', 'Yougurt'): (('Ghee',),
#   1.0),
#  ('Bread',
#   'Butter',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Milk',
#   'Panner'): (('Sugar',), 1.0),
#  ('Butter',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Milk',
#   'Sugar'): (('Panner',), 1.0),
#  ('Butter', 'Ghee', 'Panner', 'Sugar', 'Sugar', 'Yougurt'): (('Milk',), 1.0),
#  ('Bread', 'Butter', 'Cheese', 'Cheese', 'Milk', 'Yougurt'): (('Panner',),
#   1.0),
#  ('Bread', 'Bread', 'Butter', 'Cheese', 'Panner', 'Sugar'): (('Milk',), 1.0),
#  ('Bread', 'Bread', 'Butter', 'Coffee Powder', 'Panner', 'Sweet'): (('Ghee',),
#   1.0),
#  ('Bread', 'Butter', 'Ghee', 'Sugar', 'Sugar', 'Sweet'): (('Panner',), 1.0),
#  ('Bread', 'Butter', 'Panner', 'Sugar', 'Sugar', 'Sweet'): (('Ghee',), 1.0),
#  ('Bread', 'Ghee', 'Panner', 'Sugar', 'Sugar', 'Sweet'): (('Butter',), 1.0),
#  ('Milk', 'Milk', 'Milk', 'Panner', 'Sweet', 'Yougurt'): (('Sugar',), 1.0),
#  ('Bread', 'Cheese', 'Cheese', 'Cheese', 'Panner', 'Sweet'): (('Ghee',), 1.0),
#  ('Cheese',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Ghee',
#   'Milk',
#   'Sweet'): (('Panner',), 1.0),
#  ('Cheese',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Milk',
#   'Panner',
#   'Sweet'): (('Ghee',), 1.0),
#  ('Cheese',
#   'Cheese',
#   'Coffee Powder',
#   'Ghee',
#   'Sugar',
#   'Yougurt'): (('Panner',), 1.0),
#  ('Cheese', 'Cheese', 'Ghee', 'Milk', 'Panner', 'Sugar'): (('Bread',), 1.0),
#  ('Bread', 'Milk', 'Panner', 'Panner', 'Panner', 'Yougurt'): (('Cheese',),
#   1.0),
#  ('Cheese',
#   'Cheese',
#   'Lassi',
#   'Milk',
#   'Sweet',
#   'Tea Powder'): (('Coffee Powder',), 1.0),
#  ('Cheese', 'Cheese', 'Milk', 'Sweet', 'Tea Powder', 'Yougurt'): (('Sugar',),
#   1.0),
#  ('Bread',
#   'Butter',
#   'Cheese',
#   'Sugar',
#   'Tea Powder',
#   'Tea Powder'): (('Coffee Powder',), 1.0),
#  ('Bread',
#   'Cheese',
#   'Sugar',
#   'Tea Powder',
#   'Tea Powder',
#   'Tea Powder'): (('Coffee Powder',), 1.0),
#  ('Cheese',
#   'Coffee Powder',
#   'Ghee',
#   'Sweet',
#   'Tea Powder',
#   'Tea Powder'): (('Milk',), 1.0),
#  ('Cheese', 'Lassi', 'Lassi', 'Milk', 'Sweet', 'Tea Powder'): (('Butter',),
#   1.0),
#  ('Butter', 'Cheese', 'Lassi', 'Milk', 'Milk', 'Tea Powder'): (('Sweet',),
#   1.0),
#  ('Butter', 'Cheese', 'Ghee', 'Ghee', 'Lassi', 'Tea Powder'): (('Sweet',),
#   1.0),
#  ('Butter',
#   'Coffee Powder',
#   'Milk',
#   'Milk',
#   'Milk',
#   'Tea Powder'): (('Cheese',), 1.0),
#  ('Bread', 'Bread', 'Cheese', 'Milk', 'Sugar', 'Tea Powder'): (('Butter',),
#   1.0),
#  ('Butter',
#   'Cheese',
#   'Coffee Powder',
#   'Ghee',
#   'Ghee',
#   'Tea Powder'): (('Yougurt',), 1.0),
#  ('Cheese', 'Ghee', 'Lassi', 'Sweet', 'Sweet', 'Tea Powder'): (('Bread',),
#   1.0),
#  ('Bread', 'Butter', 'Butter', 'Ghee', 'Lassi', 'Tea Powder'): (('Yougurt',),
#   1.0),
#  ('Butter', 'Butter', 'Ghee', 'Lassi', 'Tea Powder', 'Yougurt'): (('Bread',),
#   1.0),
#  ('Bread', 'Butter', 'Butter', 'Milk', 'Sweet', 'Yougurt'): (('Tea Powder',),
#   1.0),
#  ('Butter', 'Butter', 'Milk', 'Sugar', 'Tea Powder', 'Yougurt'): (('Bread',),
#   1.0),
#  ('Butter', 'Butter', 'Ghee', 'Lassi', 'Milk', 'Sweet'): (('Tea Powder',),
#   1.0),
#  ('Butter', 'Butter', 'Ghee', 'Milk', 'Sweet', 'Tea Powder'): (('Lassi',),
#   1.0),
#  ('Butter',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Sugar',
#   'Tea Powder',
#   'Yougurt'): (('Ghee',), 1.0),
#  ('Butter',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Sweet',
#   'Tea Powder',
#   'Yougurt'): (('Milk',), 1.0),
#  ('Butter',
#   'Coffee Powder',
#   'Ghee',
#   'Milk',
#   'Milk',
#   'Yougurt'): (('Tea Powder',), 1.0),
#  ('Butter',
#   'Ghee',
#   'Milk',
#   'Milk',
#   'Tea Powder',
#   'Yougurt'): (('Coffee Powder',), 1.0),
#  ('Bread',
#   'Coffee Powder',
#   'Sugar',
#   'Sugar',
#   'Tea Powder',
#   'Yougurt'): (('Butter',), 1.0),
#  ('Coffee Powder',
#   'Ghee',
#   'Lassi',
#   'Tea Powder',
#   'Yougurt',
#   'Yougurt'): (('Butter',), 1.0),
#  ('Coffee Powder',
#   'Ghee',
#   'Milk',
#   'Sugar',
#   'Tea Powder',
#   'Tea Powder'): (('Lassi',), 1.0),
#  ('Bread', 'Ghee', 'Ghee', 'Lassi', 'Milk', 'Tea Powder'): (('Sweet',), 1.0),
#  ('Bread',
#   'Lassi',
#   'Sugar',
#   'Tea Powder',
#   'Tea Powder',
#   'Yougurt'): (('Sweet',), 1.0),
#  ('Coffee Powder',
#   'Lassi',
#   'Milk',
#   'Milk',
#   'Sugar',
#   'Yougurt'): (('Tea Powder',), 1.0),
#  ('Bread', 'Milk', 'Milk', 'Milk', 'Tea Powder', 'Yougurt'): (('Lassi',), 1.0),
#  ('Coffee Powder',
#   'Sugar',
#   'Sweet',
#   'Sweet',
#   'Tea Powder',
#   'Yougurt'): (('Milk',), 1.0),
#  ('Cheese', 'Ghee', 'Lassi', 'Sugar', 'Sugar', 'Sugar'): (('Butter',), 1.0),
#  ('Butter', 'Cheese', 'Milk', 'Milk', 'Sugar', 'Sweet'): (('Lassi',), 1.0),
#  ('Butter', 'Lassi', 'Milk', 'Sugar', 'Yougurt', 'Yougurt'): (('Cheese',),
#   1.0),
#  ('Cheese', 'Lassi', 'Milk', 'Sugar', 'Yougurt', 'Yougurt'): (('Butter',),
#   1.0),
#  ('Butter', 'Butter', 'Butter', 'Coffee Powder', 'Lassi', 'Sugar'): (('Milk',),
#   1.0),
#  ('Coffee Powder',
#   'Lassi',
#   'Milk',
#   'Sugar',
#   'Yougurt',
#   'Yougurt'): (('Bread',), 1.0),
#  ('Bread', 'Butter', 'Cheese', 'Sugar', 'Sugar', 'Sweet'): (('Milk',), 1.0),
#  ('Bread', 'Butter', 'Milk', 'Sugar', 'Sugar', 'Sweet'): (('Cheese',), 1.0),
#  ('Bread', 'Bread', 'Bread', 'Milk', 'Sugar', 'Sweet'): (('Butter',), 1.0),
#  ('Bread', 'Butter', 'Cheese', 'Cheese', 'Ghee', 'Sugar'): (('Sweet',), 1.0),
#  ('Bread',
#   'Cheese',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Milk',
#   'Sweet'): (('Sugar',), 1.0),
#  ('Butter', 'Butter', 'Ghee', 'Milk', 'Sugar', 'Sweet'): (('Bread',), 1.0),
#  ('Cheese', 'Coffee Powder', 'Ghee', 'Ghee', 'Sugar', 'Sweet'): (('Milk',),
#   1.0),
#  ('Butter', 'Butter', 'Cheese', 'Ghee', 'Sugar', 'Yougurt'): (('Sweet',), 1.0),
#  ('Butter', 'Cheese', 'Ghee', 'Milk', 'Yougurt', 'Yougurt'): (('Sugar',), 1.0),
#  ('Bread',
#   'Butter',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Sugar'): (('Ghee',), 1.0),
#  ('Bread', 'Butter', 'Milk', 'Sugar', 'Sugar', 'Yougurt'): (('Coffee Powder',),
#   1.0),
#  ('Cheese', 'Cheese', 'Cheese', 'Lassi', 'Sweet', 'Yougurt'): (('Butter',),
#   1.0),
#  ('Butter', 'Cheese', 'Cheese', 'Coffee Powder', 'Milk', 'Sweet'): (('Lassi',),
#   1.0),
#  ('Ghee', 'Lassi', 'Lassi', 'Milk', 'Sweet', 'Yougurt'): (('Cheese',), 1.0),
#  ('Cheese',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Milk',
#   'Sweet',
#   'Yougurt'): (('Lassi',), 1.0),
#  ('Cheese',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Milk',
#   'Sweet'): (('Lassi',), 1.0),
#  ('Bread', 'Bread', 'Cheese', 'Coffee Powder', 'Lassi', 'Yougurt'): (('Ghee',),
#   1.0),
#  ('Bread', 'Bread', 'Bread', 'Butter', 'Milk', 'Yougurt'): (('Cheese',), 1.0),
#  ('Bread', 'Cheese', 'Ghee', 'Sweet', 'Sweet', 'Yougurt'): (('Milk',), 1.0),
#  ('Bread', 'Ghee', 'Milk', 'Yougurt', 'Yougurt', 'Yougurt'): (('Cheese',),
#   1.0),
#  ('Bread', 'Butter', 'Butter', 'Cheese', 'Ghee', 'Milk'): (('Yougurt',), 1.0),
#  ('Butter',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Ghee',
#   'Sweet',
#   'Yougurt'): (('Lassi',), 1.0),
#  ('Butter',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Lassi',
#   'Sweet',
#   'Yougurt'): (('Ghee',), 1.0),
#  ('Bread',
#   'Butter',
#   'Coffee Powder',
#   'Coffee Powder',
#   'Lassi',
#   'Milk'): (('Yougurt',), 1.0),
#  ('Butter', 'Coffee Powder', 'Lassi', 'Milk', 'Sweet', 'Sweet'): (('Yougurt',),
#   1.0),
#  ('Coffee Powder', 'Ghee', 'Lassi', 'Lassi', 'Sweet', 'Yougurt'): (('Butter',),
#   1.0)}
